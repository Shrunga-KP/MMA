# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread('udupi karnataka.png')
print("Original image")
cv2_imshow(img)
# Out:
# Original image
# <PIL.Image.Image image mode=RGB size=497x92 at 0x7F8C92FC86A0>

# %%
img.shape
# Out:
# (92, 497, 3)

# %%
img.ndim
# Out:
# 3

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
lower_blue = np.array([0,0,60])
upper_blue = np.array([255,255,255])

# %%
mask = cv2.inRange(hsv, lower_blue, upper_blue)
cv2_imshow(mask)
# Out:
# <PIL.Image.Image image mode=L size=497x92 at 0x7F8C92FC8F70>

# %%
res = cv2.bitwise_and(img[:52,90:200],img[:52,90:200], mask= mask[:52,90:200])
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=RGB size=110x52 at 0x7F8C92FC93C0>

# %%
red = np.uint8([[[255,0,0 ]]])
hsv_red = cv2.cvtColor(red,cv2.COLOR_BGR2HSV)
print( hsv_red )
# Out:
# [[[120 255 255]]]

# %%
lower_red = np.array([160,20,70])
upper_red = np.array([180,255,255])

mask1 = cv2.inRange(hsv, lower_red, upper_red)
cv2_imshow(mask1)
# Out:
# <PIL.Image.Image image mode=L size=497x92 at 0x7F8C92FC87F0>

# %%
lower_red = np.array([0,0,70])
upper_red = np.array([180,255,255])

# %%
mask1 = cv2.inRange(hsv, lower_red, upper_red)
cv2_imshow(mask1)
# Out:
# <PIL.Image.Image image mode=L size=497x92 at 0x7F8C92FC85B0>

# %%
res = cv2.bitwise_and(img[:50,280:],img[:50,280:], mask= mask1[:50,280:])
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=RGB size=217x50 at 0x7F8C92FC8EB0>

# %% [markdown]
# Green Colour Detection

# %%
#color detection of red and green color in image

#necessary libraries

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
green = np.uint8([[[0, 255, 0]]])  #green color
hsvGreen = cv2.cvtColor(green, cv2.COLOR_BGR2HSV) #hsv value of green color
print(hsvGreen)

lowerLimit = hsvGreen[0][0][0] - 10, 100, 100  # range of green color lower limit and upper limit
upperLimit = hsvGreen[0][0][0] + 10, 255, 255

print(upperLimit)
print(lowerLimit)
# Out:
# [[[ 60 255 255]]]
# (70, 255, 255)
# (50, 100, 100)

# %%
red = np.uint8([[[0, 0, 255]]]) #red color
hsvred = cv2.cvtColor(red, cv2.COLOR_BGR2HSV) #hsv value of red color
print(hsvred)

lower = hsvred[0][0][0] - 10, 100, 100 # range of red color lower limit and upper limit
upper = hsvred[0][0][0] + 10, 255, 255

print(upper)
print(lower)
# Out:
# [[[  0 255 255]]]
# (10, 255, 255)
# (-10, 100, 100)

# %%
image = cv2.imread(r'Image.jpg') #load your image
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV) #convert the image into hsv

lg = np.array(lowerLimit) #range of green color
ug = np.array(upperLimit)

green_mask = cv2.inRange(hsv, lg, ug) #green masked image
print('Green Mask')
cv2_imshow(green_mask) #show the image

res = cv2.bitwise_and(image, image, mask = green_mask)

print('Image with Green Region only')
cv2_imshow(res)
# Out:
# Green Mask
# <PIL.Image.Image image mode=L size=200x200>
# Image with Green Region only
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
lr = np.array(lower) #range of red color
ur = np.array(upper)

red_mask = cv2.inRange(hsv, lr, ur) #red masked image
print('red')
cv2_imshow(red_mask)  #show the image  Mask


res = cv2.bitwise_and(image, image, mask = red_mask)

print('Image with Red Region only')
cv2_imshow(res)
# Out:
# red
# <PIL.Image.Image image mode=L size=200x200>
# Image with Red Region only
# <PIL.Image.Image image mode=RGB size=200x200>
