# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading audio files with Librosa

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
scale_file = "/content/drive/MyDrive/Second Sem/data/salaar_bgm.mp3"

# %%
ipd.Audio(scale_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# load audio files with librosa
scale, sr = librosa.load(scale_file)

# %% [markdown]
# ## Mel filter banks

# %%
filter_banks = librosa.filters.mel(n_fft=2048, sr=22050, n_mels=10)

# %%
filter_banks.shape
# Out:
# (10, 1025)

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(filter_banks,
                         sr=sr,
                         x_axis="linear")
plt.colorbar(format="%+2.f")
plt.show()

# %% [markdown]
# ## Extracting Mel Spectrogram

# %%
mel_spectrogram = librosa.feature.melspectrogram(y=scale, sr=sr, n_fft=2048, hop_length=512, n_mels=10)

# %%
mel_spectrogram.shape
# Out:
# (10, 1292)

# %%
log_mel_spectrogram = librosa.power_to_db(mel_spectrogram)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8dd1f808a372> in <cell line: 1>()
# ----> 1 log_mel_spectrogram = librosa.power_to_db(mel_spectrogram)
#
# NameError: name 'librosa' is not defined

# %%
log_mel_spectrogram.shape
# Out:
# (10, 1292)

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(log_mel_spectrogram,
                         x_axis="time",
                         y_axis="mel",
                         sr=sr)
plt.colorbar(format="%+2.f")
plt.show()
